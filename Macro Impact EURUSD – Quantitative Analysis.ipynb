# %%
#%% Cell 1: Check current numpy version
import numpy as np
print("Current NumPy version:", np.__version__)

#%% Cell 2: Downgrade NumPy (run this cell ONCE then RESTART KERNEL)
# This uses IPython magic commands to run shell commands from Python
# %pip uninstall -y numpy
# %pip install "numpy<2"

# After running this cell, you MUST restart your kernel:
# Kernel -> Restart Kernel from Jupyter menu

#%% Cell 3: Verify after restart (run after kernel restart)
import numpy as np
print("New NumPy version:", np.__version__)
# Out:
# Current NumPy version: 2.2.5
# Found existing installation: numpy 2.2.5
# Uninstalling numpy-2.2.5:
#   Successfully uninstalled numpy-2.2.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\rahul\AppData\Roaming\Python\Python312\site-packages\~umpy.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\rahul\AppData\Roaming\Python\Python312\site-packages\~umpy'.
# You can safely remove it manually.

# %%
import numpy as np
print("New NumPy version:", np.__version__)
# Out:
# New NumPy version: 1.26.4

# %%
#%% Cell 2a: Reinstall key packages (optional but recommended)
# %pip install --force-reinstall pandas yfinance matplotlib seaborn scikit-learn
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached yfinance-0.2.58-py2.py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached platformdirs-4.3.7-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# ...
#   Using cached peewee-3.18.1-py3-none-any.whl
# ...
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached curl_cffi-0.10.0-cp39-abi3-win_amd64.whl.metadata (12 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...

# %%
#%% Generate conda environment commands (copy output to terminal)
env_name = "fx_analysis"
print(f"Run these in your terminal:\n"
      f"conda create -n {env_name} python=3.10 numpy=1.23 pandas matplotlib yfinance pandas-datareader scikit-learn\n"
      f"conda activate {env_name}\n"
      "jupyter notebook")
# Out:
# Run these in your terminal:
# conda create -n fx_analysis python=3.10 numpy=1.23 pandas matplotlib yfinance pandas-datareader scikit-learn
# conda activate fx_analysis
# jupyter notebook

# %%
#%% For Anaconda users
import sys
# !conda install --yes --prefix {sys.prefix} python-dateutil
# Out:
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\rahul\anaconda3
#
#   added / updated specs:
#     - python-dateutil
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     frozendict-2.4.2           |  py312haa95532_0          38 KB
#     packaging-24.2             |  py312haa95532_0         196 KB
#     platformdirs-4.3.7         |  py312haa95532_0          41 KB
#     six-1.17.0                 |  py312haa95532_0          38 KB
#     ------------------------------------------------------------
#                                            Total:         357 KB
#
# The following NEW packages will be INSTALLED:
#
#   charset-normalizer pkgs/main/noarch::charset-normalizer-3.3.2-pyhd3eb1b0_0
# ...

# %%
#%% Create a new clean environment (run this cell and copy the output commands to your terminal)
import sys
print(f"conda create -n fx_analysis python=3.10 numpy=1.23 pandas matplotlib python-dateutil yfinance pandas-datareader scikit-learn")
print(f"conda activate fx_analysis")
print(f"python -m ipykernel install --user --name fx_analysis --display-name 'FX Analysis'")
print("\nCOPY THESE COMMANDS TO YOUR TERMINAL AND RUN THEM")
# Out:
# conda create -n fx_analysis python=3.10 numpy=1.23 pandas matplotlib python-dateutil yfinance pandas-datareader scikit-learn
# conda activate fx_analysis
# python -m ipykernel install --user --name fx_analysis --display-name 'FX Analysis'
#
# COPY THESE COMMANDS TO YOUR TERMINAL AND RUN THEM

# %%
#%% Cell 1: Create clean environment (run once, then restart)
print("""
1. Open Anaconda Prompt
2. Run these commands:
conda create -n fx_analysis python=3.10 numpy=1.23.5 pandas=1.5.3 matplotlib=3.7.1 pandas-datareader=0.10.0 yfinance=0.2.28 scikit-learn=1.2.2 python-dateutil=2.8.2 numexpr=2.8.4 bottleneck=1.3.7 -c conda-forge -y
conda activate fx_analysis
conda install -c conda-forge jupyter -y
""")
print("AFTER CREATING ENVIRONMENT, RESTART JUPYTER FROM THIS NEW ENVIRONMENT")
# Out:
# 1. Open Anaconda Prompt
# 2. Run these commands:
# conda create -n fx_analysis python=3.10 numpy=1.23.5 pandas=1.5.3 matplotlib=3.7.1 pandas-datareader=0.10.0 yfinance=0.2.28 scikit-learn=1.2.2 python-dateutil=2.8.2 numexpr=2.8.4 bottleneck=1.3.7 -c conda-forge -y
# conda activate fx_analysis
# conda install -c conda-forge jupyter -y
#
# AFTER CREATING ENVIRONMENT, RESTART JUPYTER FROM THIS NEW ENVIRONMENT

# %%
print("conda env remove -n fx_analysis")
# Out:
# conda env remove -n fx_analysis

# %%
print("conda activate fx_analysis && jupyter notebook")
# Out:
# conda activate fx_analysis && jupyter notebook

# %%
#%% Cell 0: Ensure conda environment is properly set up
import os
print("Make sure you're using the 'fx_analysis' kernel!")
print("Current python path:", os.sys.executable)
# Out:
# Make sure you're using the 'fx_analysis' kernel!
# Current python path: C:\Users\rahul\anaconda3\python.exe

# %%
#%% Cell 1a: Alternative install with user privileges
import sys
# !{sys.executable} -m pip install pandas-datareader --user
# Out:
# ...
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# ...
# Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# ...

# %%
#%% 1. Import Libraries
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader import data as web

sns.set(style='whitegrid')

#%% 2. Fetch Data Correctly
start_date = '2000-01-01'
end_date = pd.Timestamp.today().strftime('%Y-%m-%d')

# Fetch FX Data (returns DataFrame with single 'Close' column)
eurusd = yf.download('EURUSD=X', start_date, end_date)[['Close']].rename(
    columns={'Close': 'EURUSD'}
)

# Fetch Macro Data from FRED
macro_data = web.DataReader(
    ['DGS10', 'FEDFUNDS', 'CPIAUCSL', 'DTWEXBGS'], 
    'fred', 
    start_date, 
    end_date
)
macro_data.columns = ['US10Y', 'FFR', 'CPI', 'DXY']

#%% 3. Data Processing
# Merge datasets (now both are DataFrames)
df = pd.concat([eurusd, macro_data], axis=1).ffill().dropna()

# Continue with your analysis...
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#%% 1. Add Date Validation
from datetime import datetime

def validate_dates(start, end):
    today = datetime.today().date()
    if end.date() > today:
        print(f"WARNING: Resetting end date from {end.date()} to {today}")
        end = today.strftime('%Y-%m-%d')
    return start, end

#%% 2. Modified Data Fetching
start_date = '2000-01-01'
end_date = pd.Timestamp.today()
start_date, end_date = validate_dates(start_date, end_date)

# Fetch FX Data (corrected)
eurusd = yf.download('EURUSD=X', start_date, end_date)[['Close']].rename(
    columns={'Close': 'EURUSD'}
)

# Fetch Macro Data (verified)
macro_data = web.DataReader(
    ['DGS10', 'FEDFUNDS', 'CPIAUCSL', 'DTWEXBGS'], 
    'fred', 
    start_date, 
    end_date
)
macro_data.columns = ['US10Y', 'FFR', 'CPI', 'DXY']

#%% 3. Data Cleaning
# Remove future dates that might come from FRED
df = pd.concat([eurusd, macro_data], axis=1)
df = df[df.index <= pd.Timestamp.today().floor('D')]  # Remove future dates
df = df.ffill().dropna()

#%% 4. Final Verification
print("\nVALIDATED DATA:")
print(f"Date Range: {df.index[0].date()} to {df.index[-1].date()}")
print(f"Shape: {df.shape}")
print(df.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# VALIDATED DATA:
# Date Range: 2006-01-02 to 2025-05-02
# Shape: (5111, 5)
#             (EURUSD, EURUSD=X)  US10Y   FFR      CPI       DXY
# 2025-04-28            1.134314   4.23  4.33  319.615  123.2454
# 2025-04-29            1.140914   4.19  4.33  319.615  123.2454
# 2025-04-30            1.138926   4.17  4.33  319.615  123.2454
# 2025-05-01            1.132490   4.25  4.33  319.615  123.2454
# 2025-05-02            1.129650   4.25  4.33  319.615  123.2454

# %%
import datetime
print("Actual System Date:", datetime.datetime.now().date())
# Out:
# Actual System Date: 2025-05-04

# %%
pip install fredapi
# Out:
# ...
#
# ...

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.1

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from fredapi import Fred
from datetime import datetime

# Set plot style
plt.style.use('seaborn-v0_8')
sns.set_palette("deep")

# 1. Pull Data
# Initialize FRED API with provided API key
fred = Fred(api_key='e1020df616b278b14d10a28764a8b2a1')

# Define date range
start_date = '2006-01-01'
end_date = '2025-05-04'

# Pull EUR/USD from yfinance with error handling
try:
    eurusd = yf.download('EURUSD=X', start=start_date, end=end_date, progress=False)
    if eurusd.empty:
        raise ValueError("No EUR/USD data retrieved from yfinance.")
    # Handle MultiIndex and ensure EURUSD column
    close_data = eurusd['Close']
    print("Type of eurusd['Close']:", type(close_data))
    if isinstance(close_data, pd.Series):
        eurusd = close_data.to_frame().rename(columns={'Close': 'EURUSD'})
    elif isinstance(close_data, pd.DataFrame):
        eurusd = close_data.rename(columns={close_data.columns[0]: 'EURUSD'})
    else:
        raise ValueError(f"Unexpected type for eurusd['Close']: {type(close_data)}")
    print("EUR/USD Data Retrieved:")
    print(eurusd.head())
    print(eurusd.tail())
    print("EUR/USD Columns:", eurusd.columns.tolist())
except Exception as e:
    print(f"Error retrieving EUR/USD data: {e}")
    raise

# Pull macro indicators from FRED with flexible handling
def fetch_fred_series(series_id, name):
    data = fred.get_series(series_id, start_date=start_date, end_date=end_date)
    print(f"FRED {series_id} Type:", type(data))
    print(f"FRED {series_id} Head:", data.head())
    if isinstance(data, pd.Series):
        return data.to_frame(name=name)
    elif isinstance(data, pd.DataFrame):
        return data.rename(columns={data.columns[0]: name})
    else:
        raise ValueError(f"Unexpected data type for {series_id}: {type(data)}")

# Fetch FRED series
us10y = fetch_fred_series('DGS10', 'US10Y')
ffr = fetch_fred_series('FEDFUNDS', 'FFR')
cpi = fetch_fred_series('CPIAUCSL', 'CPI')
dxy = fetch_fred_series('DTWEXBGS', 'DXY')

# 2. Data Wrangling
# Combine all data into a single DataFrame
data = eurusd.join([us10y, ffr, cpi, dxy], how='outer')

# Forward fill missing values and drop any remaining NaNs
data = data.ffill().dropna()

# Check if EURUSD column exists
if 'EURUSD' not in data.columns:
    raise KeyError("EURUSD column missing in combined DataFrame. Check data retrieval or join operation.")

# Calculate daily returns for EUR/USD
data['EURUSD_Returns'] = data['EURUSD'].pct_change()

# Ensure data aligns with your validated shape (5111 rows, 5 columns + returns)
print("Data Shape:", data.shape)
print("Combined Data Tail:")
print(data.tail())

# 3. Analytics and Visualizations
# Time-series trend plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['EURUSD'], label='EUR/USD', color='blue')
plt.title('EUR/USD Trend (2006-2025)', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('EUR/USD', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Rolling correlation (90-day window) between EUR/USD returns and macro indicators
# Create a DataFrame to store correlations
corr_data = pd.DataFrame(index=data.index)
for col in ['US10Y', 'FFR', 'CPI', 'DXY']:
    corr_data[col] = data['EURUSD_Returns'].rolling(window=90).corr(data[col])
corr_data = corr_data.dropna()
corr_data['Date'] = corr_data.index
print("Correlation Data Shape:", corr_data.shape)
print("Correlation Data Columns:", corr_data.columns.tolist())
print("Correlation Data Head:")
print(corr_data.head())
print("Correlation Data Tail:")
print(corr_data.tail())

# Check if correlation data is empty
if corr_data.empty:
    print("Warning: Correlation data is empty. No plot will be generated.")
else:
    # Plot rolling correlations
    plt.figure(figsize=(12, 6))
    for col in ['US10Y', 'FFR', 'CPI', 'DXY']:
        plt.plot(corr_data['Date'], corr_data[col], label=f'EUR/USD vs {col}')
    plt.title('90-Day Rolling Correlation of EUR/USD Returns with Macro Indicators', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Correlation', fontsize=12)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Volatility (30-day rolling standard deviation of EUR/USD returns)
data['EURUSD_Volatility'] = data['EURUSD_Returns'].rolling(window=30).std() * np.sqrt(252)  # Annualized
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['EURUSD_Volatility'], label='EUR/USD Volatility (30-day)', color='red')
plt.title('EUR/USD Annualized Volatility (2006-2025)', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Volatility', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Overlay EUR/USD with CPI
fig, ax1 = plt.subplots(figsize=(12, 6))
ax1.plot(data.index, data['EURUSD'], color='blue', label='EUR/USD')
ax1.set_xlabel('Date', fontsize=12)
ax1.set_ylabel('EUR/USD', color='blue', fontsize=12)
ax1.tick_params(axis='y', labelcolor='blue')
ax2 = ax1.twinx()
ax2.plot(data.index, data['CPI'], color='green', label='CPI')
ax2.set_ylabel('CPI', color='green', fontsize=12)
ax2.tick_params(axis='y', labelcolor='green')
plt.title('EUR/USD vs CPI (2006-2025)', fontsize=14)
fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# 4. Basic Backtest (SMA Crossover Strategy)
# Calculate SMAs
data['SMA_Short'] = data['EURUSD'].rolling(window=20).mean()
data['SMA_Long'] = data['EURUSD'].rolling(window=50).mean()

# Generate signals
data['Signal'] = 0
data['Signal'] = np.where(data['SMA_Short'] > data['SMA_Long'], 1, -1)

# Calculate strategy returns
data['Strategy_Returns'] = data['EURUSD_Returns'] * data['Signal'].shift(1)

# Cumulative returns
data['Cumulative_Strategy'] = (1 + data['Strategy_Returns']).cumprod()
data['Cumulative_BuyHold'] = (1 + data['EURUSD_Returns']).cumprod()

# Plot equity curve
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Cumulative_Strategy'], label='SMA Crossover Strategy', color='purple')
plt.plot(data.index, data['Cumulative_BuyHold'], label='Buy and Hold', color='blue')
plt.title('SMA Crossover Strategy vs Buy and Hold', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Returns', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Risk Metrics
# Annualized Sharpe Ratio
sharpe_ratio = (data['Strategy_Returns'].mean() * 252) / (data['Strategy_Returns'].std() * np.sqrt(252))
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")

# Maximum Drawdown
rolling_max = data['Cumulative_Strategy'].cummax()
drawdown = (data['Cumulative_Strategy'] - rolling_max) / rolling_max
max_drawdown = drawdown.min()
print(f"Maximum Drawdown: {max_drawdown:.2%}")

# 5. Save Data (Optional)
data.to_csv('eurusd_macro_analysis.csv')
print("Data saved to 'eurusd_macro_analysis.csv'")
# Out:
# Type of eurusd['Close']: <class 'pandas.core.frame.DataFrame'>
# EUR/USD Data Retrieved:
# Ticker        EURUSD
# Date
# 2006-01-02  1.181698
# 2006-01-03  1.203297
# 2006-01-04  1.211196
# 2006-01-05  1.210698
# 2006-01-06  1.215407
# Ticker        EURUSD
# Date
# 2025-04-28  1.134314
# 2025-04-29  1.140914
# 2025-04-30  1.138926
# 2025-05-01  1.132490
# 2025-05-02  1.129650
# EUR/USD Columns: ['EURUSD']
# FRED DGS10 Type: <class 'pandas.core.series.Series'>
# FRED DGS10 Head: 1962-01-02    4.06
# 1962-01-03    4.03
# 1962-01-04    3.99
# 1962-01-05    4.02
# 1962-01-08    4.03
# dtype: float64
# FRED FEDFUNDS Type: <class 'pandas.core.series.Series'>
# FRED FEDFUNDS Head: 1954-07-01    0.80
# 1954-08-01    1.22
# 1954-09-01    1.07
# 1954-10-01    0.85
# 1954-11-01    0.83
# dtype: float64
# FRED CPIAUCSL Type: <class 'pandas.core.series.Series'>
# FRED CPIAUCSL Head: 1947-01-01    21.48
# 1947-02-01    21.62
# 1947-03-01    22.00
# 1947-04-01    22.00
# 1947-05-01    21.95
# ...

# %%
window_start = year - pd.Timedelta(days=90)
window_end = year + pd.Timedelta(days=90)

# %%
# Install libraries silently
# !pip install --quiet numpy==1.26.4 pandas yfinance fredapi statsmodels matplotlib seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from fredapi import Fred
import statsmodels.api as sm

# Set plot style
plt.style.use('seaborn-v0_8')
sns.set_palette("deep")

# Define date range
start_date = '2006-01-01'
end_date = '2024-12-31'

# Initialize FRED API
fred = Fred(api_key='e1020df616b278b14d10a28764a8b2a1')

# Pull EUR/USD from yfinance
try:
    eurusd = yf.download('EURUSD=X', start=start_date, end=end_date, progress=False)
    if eurusd.empty:
        raise ValueError("No EUR/USD data retrieved from yfinance.")
    close_data = eurusd['Close']
    print("Type of eurusd['Close']:", type(close_data))
    if isinstance(close_data, pd.Series):
        eurusd = close_data.to_frame(name='EURUSD')
    elif isinstance(close_data, pd.DataFrame):
        eurusd = close_data.rename(columns={close_data.columns[0]: 'EURUSD'})
    else:
        raise ValueError(f"Unexpected type for eurusd['Close']: {type(close_data)}")
    eurusd = eurusd.loc[:end_date]  # Enforce end date
    print("EUR/USD Data Retrieved:")
    print(eurusd.head())
    print(eurusd.tail())
    print("EUR/USD Columns:", eurusd.columns.tolist())
except Exception as e:
    print(f"Error retrieving EUR/USD data: {e}")
    raise

# Pull macro indicators from FRED
def fetch_fred_series(series_id, name):
    try:
        data = fred.get_series(series_id, start_date=start_date, end_date=end_date)
        print(f"FRED {series_id} Type:", type(data))
        print(f"FRED {series_id} Head:", data.head())
        if isinstance(data, pd.Series):
            data = data.to_frame(name=name)
        elif isinstance(data, pd.DataFrame):
            data = data.rename(columns={data.columns[0]: name})
        else:
            raise ValueError(f"Unexpected data type for {series_id}: {type(data)}")
        data = data.loc[:end_date]  # Enforce end date
        return data
    except Exception as e:
        print(f"Error retrieving FRED series {series_id}: {e}")
        raise

us10y = fetch_fred_series('DGS10', 'US10Y')
ffr = fetch_fred_series('FEDFUNDS', 'FFR')
cpi = fetch_fred_series('CPIAUCSL', 'CPI')
dxy = fetch_fred_series('DTWEXBGS', 'DXY')

# Combine and clean data
data = eurusd.join([us10y, ffr, cpi, dxy], how='outer')
data = data.loc[:end_date].ffill().dropna()  # Enforce end date, use trading days

# Calculate returns
data['EURUSD_Returns'] = data['EURUSD'].pct_change()
data['US10Y_Returns'] = data['US10Y'].pct_change()
data['FFR_Returns'] = data['FFR'].pct_change()
data['CPI_Returns'] = data['CPI'].pct_change()
data['DXY_Returns'] = data['DXY'].pct_change()
data = data.dropna()

# Verify data
print("Data Shape:", data.shape)
print("Data Columns:", data.columns.tolist())
print("Combined Data Tail:")
print(data.tail())

# Rolling correlations (90-day window)
corr_data = pd.DataFrame(index=data.index)
for col in ['US10Y_Returns', 'FFR_Returns', 'CPI_Returns', 'DXY_Returns']:
    corr_data[col] = data['EURUSD_Returns'].rolling(window=90).corr(data[col])
corr_data = corr_data.dropna()
corr_data['Date'] = corr_data.index
print("Correlation Data Shape:", corr_data.shape)
print("Correlation Data Columns:", corr_data.columns.tolist())
print("Correlation Data Head:")
print(corr_data.head())
print("Correlation Data Tail:")
print(corr_data.tail())

# Plot rolling correlations
if not corr_data.empty:
    plt.figure(figsize=(12, 6))
    for col in ['US10Y_Returns', 'FFR_Returns', 'CPI_Returns', 'DXY_Returns']:
        plt.plot(corr_data['Date'], corr_data[col], label=f'EUR/USD vs {col.replace("_Returns", "")}')
    plt.title('90-Day Rolling Correlation of EUR/USD Returns with Macro Factors', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Correlation', fontsize=12)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Warning: No correlation data to plot.")

# Heatmaps of correlation matrices
years = pd.date_range(start='2006-01-01', end='2024-12-31', freq='2YE')
for year in years:
    window_start = year - pd.Timedelta(days=45)
    window_end = year + pd.Timedelta(days=45)
    window_data = data.loc[window_start:window_end, ['EURUSD_Returns', 'US10Y_Returns', 'FFR_Returns', 'CPI_Returns', 'DXY_Returns']]
    if len(window_data) < 10:
        print(f"Skipping heatmap for {year.strftime('%Y-%m-%d')}: insufficient data ({len(window_data)} rows)")
        continue
    corr_matrix = window_data.corr()
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
    plt.title(f'Correlation Matrix around {year.strftime("%Y-%m-%d")}', fontsize=14)
    plt.tight_layout()
    plt.show()

# OLS Regression
X = data[['US10Y_Returns', 'FFR_Returns', 'CPI_Returns', 'DXY_Returns']]
X = sm.add_constant(X)
y = data['EURUSD_Returns']
model = sm.OLS(y, X, missing='drop').fit()
print("\nOLS Regression Results:")
print(model.summary())

# Save data
data.to_csv('eurusd_macro_correlation_analysis.csv')
print("Data saved to 'eurusd_macro_correlation_analysis.csv'")
# Out:
# Type of eurusd['Close']: <class 'pandas.core.frame.DataFrame'>
# EUR/USD Data Retrieved:
# Ticker        EURUSD
# Date
# 2006-01-02  1.181698
# 2006-01-03  1.203297
# 2006-01-04  1.211196
# 2006-01-05  1.210698
# 2006-01-06  1.215407
# Ticker        EURUSD
# Date
# 2024-12-24  1.040583
# 2024-12-25  1.040258
# 2024-12-26  1.039955
# 2024-12-27  1.042318
# 2024-12-30  1.042938
# EUR/USD Columns: ['EURUSD']
# FRED DGS10 Type: <class 'pandas.core.series.Series'>
# FRED DGS10 Head: 1962-01-02    4.06
# 1962-01-03    4.03
# 1962-01-04    3.99
# 1962-01-05    4.02
# 1962-01-08    4.03
# dtype: float64
# FRED FEDFUNDS Type: <class 'pandas.core.series.Series'>
# FRED FEDFUNDS Head: 1954-07-01    0.80
# 1954-08-01    1.22
# 1954-09-01    1.07
# 1954-10-01    0.85
# 1954-11-01    0.83
# dtype: float64
# FRED CPIAUCSL Type: <class 'pandas.core.series.Series'>
# FRED CPIAUCSL Head: 1947-01-01    21.48
# 1947-02-01    21.62
# 1947-03-01    22.00
# 1947-04-01    22.00
# 1947-05-01    21.95
# ...

# %%
FRED_API_KEY = "e1020df616b278b14d10a28764a8b2a1"
fred = Fred(api_key=FRED_API_KEY)

# %%
# EUR/USD MACRO IMPACT – A Quantitative Analysis using Python

"""
🔧 ENVIRONMENT SETUP (to run this notebook smoothly)
Run the following commands in your terminal or Anaconda Prompt:

Step 1: Activate your base environment:
    conda activate base

Step 2: Update Conda:
    conda update -n base conda

Step 3: Remove conflicting packages (if any):
    conda remove tensorflow h5py numpy --force

Step 4: Install required libraries:
    conda install numpy=1.23.5 pandas matplotlib seaborn scikit-learn jupyter -c conda-forge
    pip install --quiet yfinance fredapi statsmodels xgboost ta

"""

# ✅ STEP 1: IMPORT LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime

# Optional: Include FRED setup only if user has access
try:
    from fredapi import Fred
    FRED_API_KEY = "e1020df616b278b14d10a28764a8b2a1"  # Your working FRED API key
    fred = Fred(api_key=FRED_API_KEY)
    use_fred = True
except ModuleNotFoundError:
    print("fredapi not found. Macro data from FRED will be skipped.")
    use_fred = False

# ✅ STEP 2: PULL FX AND MACRO DATA
start_date = "2010-01-01"
end_date = datetime.today().strftime('%Y-%m-%d')

# EUR/USD exchange rate from Yahoo Finance
eurusd = yf.download("EURUSD=X", start=start_date, end=end_date)[["Close"]]
eurusd.columns = ["EURUSD"]

# Pull macro indicators from FRED if available
if use_fred:
    us_10y = fred.get_series("DGS10", observation_start=start_date)
    fed_funds = fred.get_series("FEDFUNDS", observation_start=start_date)
    cpi = fred.get_series("CPIAUCSL", observation_start=start_date)
    dollar_index = fred.get_series("DTWEXBGS", observation_start=start_date)

    # ✅ STEP 3: DATA WRANGLING
    data = pd.concat([eurusd, us_10y, fed_funds, cpi, dollar_index], axis=1)
    data.columns = ["EURUSD", "US10Y", "FEDFUNDS", "CPI", "DOLLAR_IDX"]
else:
    data = pd.DataFrame(eurusd)
    print("Only EUR/USD data available due to missing fredapi.")

# Forward fill missing values
if use_fred:
    data = data.fillna(method="ffill")

# ✅ STEP 4: ANALYSIS & VISUALIZATION
plt.figure(figsize=(14, 6))
plt.plot(data["EURUSD"], label="EUR/USD")
plt.title("EUR/USD Exchange Rate")
plt.legend()
plt.show()

if use_fred:
    rolling_corr = data["EURUSD"].rolling(window=180).corr(data["CPI"])
    plt.figure(figsize=(14, 5))
    plt.plot(rolling_corr, label="180-day Rolling Corr: EURUSD vs CPI")
    plt.title("Rolling Correlation")
    plt.legend()
    plt.show()

# Rolling volatility
data['EURUSD_vol'] = data['EURUSD'].pct_change().rolling(window=30).std() * np.sqrt(252)
plt.figure(figsize=(14, 5))
plt.plot(data['EURUSD_vol'], label='30-day Annualized Volatility')
plt.title("EUR/USD Volatility")
plt.legend()
plt.show()

# ✅ STEP 5: STRATEGY BACKTEST (Simple SMA crossover)
data['SMA50'] = data['EURUSD'].rolling(window=50).mean()
data['SMA200'] = data['EURUSD'].rolling(window=200).mean()
data['Position'] = np.where(data['SMA50'] > data['SMA200'], 1, 0)
data['Returns'] = data['EURUSD'].pct_change()
data['Strategy'] = data['Position'].shift(1) * data['Returns']

# Strategy equity curve
(1 + data[['Returns', 'Strategy']]).cumprod().plot(figsize=(14, 6))
plt.title("SMA Crossover Strategy vs Buy & Hold")
plt.ylabel("Cumulative Returns")
plt.show()

# ✅ STEP 6: SHARPE RATIO
sharpe_strategy = (data['Strategy'].mean() / data['Strategy'].std()) * np.sqrt(252)
sharpe_bh = (data['Returns'].mean() / data['Returns'].std()) * np.sqrt(252)
print(f"Sharpe Ratio (Strategy): {sharpe_strategy:.2f}")
print(f"Sharpe Ratio (Buy & Hold): {sharpe_bh:.2f}")

# ✅ STEP 7: SUMMARY
# In your notebook markdown, explain:
# - FX-macro interactions
# - Correlation & volatility takeaways
# - Strategy logic & risk metrics
# - Resume-ready skills shown: real-world data use, returns logic, macro understanding
# Out:
# [*********************100%***********************]  1 of 1 completed
# Sharpe Ratio (Strategy): -0.16
# Sharpe Ratio (Buy & Hold): -0.13

# %%
# ✅ CREATE FEATURES
# Lag EUR/USD returns
data['EURUSD_Returns'] = data['EURUSD'].pct_change()
data['Lag1'] = data['EURUSD_Returns'].shift(1)
data['Lag2'] = data['EURUSD_Returns'].shift(2)
data['Lag3'] = data['EURUSD_Returns'].shift(3)

# Normalize/lag macro indicators if FRED data is available
if use_fred:
    data['DXY_Change'] = data['DOLLAR_IDX'].pct_change().shift(1)
    data['CPI_Change'] = data['CPI'].pct_change().shift(1)
    data['FFR_Change'] = data['FEDFUNDS'].diff().shift(1)
    data['US10Y_Change'] = data['US10Y'].diff().shift(1)

# Drop NA values
data.dropna(inplace=True)

# ✅ DEFINE LABEL
# 1 if return is positive (price up), 0 if negative/down
data['Target'] = (data['EURUSD_Returns'].shift(-1) > 0).astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

# ✅ SELECT FEATURES
features = ['Lag1', 'Lag2', 'Lag3']
if use_fred:
    features += ['DXY_Change', 'CPI_Change', 'FFR_Change', 'US10Y_Change']

X = data[features]
y = data['Target']

# ✅ SPLIT DATA
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# ✅ Decision Tree
dt_model = DecisionTreeClassifier(max_depth=5, random_state=42)
dt_model.fit(X_train, y_train)

# ✅ Random Forest
rf_model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
# Evaluate Decision Tree
print("Decision Tree Performance:")
y_pred_dt = dt_model.predict(X_test)
print(confusion_matrix(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))

# Evaluate Random Forest
print("Random Forest Performance:")
y_pred_rf = rf_model.predict(X_test)
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Decision Tree Performance:
# [[232 170]
#  [231 138]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.58      0.54       402
#            1       0.45      0.37      0.41       369
#
#     accuracy                           0.48       771
#    macro avg       0.47      0.48      0.47       771
# weighted avg       0.48      0.48      0.47       771
#
# Random Forest Performance:
# [[266 136]
#  [244 125]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.66      0.58       402
#            1       0.48      0.34      0.40       369
#
#     accuracy                           0.51       771
#    macro avg       0.50      0.50      0.49       771
# weighted avg       0.50      0.51      0.49       771

# %%
importances = rf_model.feature_importances_
feature_names = X.columns

# Plot
plt.figure(figsize=(10, 5))
plt.barh(feature_names, importances, color='skyblue')
plt.xlabel("Feature Importance")
plt.title("Random Forest Feature Importance")
plt.gca().invert_yaxis()
plt.show()

# %%
y_prob = rf_model.predict_proba(X_test)[:, 1]
y_custom = (y_prob > 0.6).astype(int)
print(classification_report(y_test, y_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68       402
#            1       0.00      0.00      0.00       369
#
#     accuracy                           0.52       771
#    macro avg       0.26      0.50      0.34       771
# weighted avg       0.27      0.52      0.36       771

# %%
# !pip install ta --quiet

# %%
from ta.trend import SMAIndicator
from ta.momentum import RSIIndicator
from ta.trend import MACD

# Add SMA indicators
sma_20 = SMAIndicator(close=data['EURUSD'], window=20)
sma_50 = SMAIndicator(close=data['EURUSD'], window=50)
data['SMA_20'] = sma_20.sma_indicator()
data['SMA_50'] = sma_50.sma_indicator()
data['SMA_diff'] = data['SMA_20'] - data['SMA_50']

# Add RSI
rsi = RSIIndicator(close=data['EURUSD'], window=14)
data['RSI'] = rsi.rsi()

# Add MACD
macd = MACD(close=data['EURUSD'])
data['MACD'] = macd.macd()
data['MACD_signal'] = macd.macd_signal()

# Drop any NA values from indicators
data.dropna(inplace=True)

# Preview the new features
data[['EURUSD', 'SMA_20', 'SMA_50', 'RSI', 'MACD', 'MACD_signal']].tail()
# Out:
#               EURUSD    SMA_20    SMA_50        RSI      MACD  MACD_signal
# 2025-04-29  1.140914  1.121600  1.091134  65.370276  0.015014     0.015489
# 2025-04-30  1.138926  1.124567  1.093070  63.795999  0.014444     0.015280
# 2025-05-01  1.132490  1.126648  1.094719  58.854312  0.013319     0.014888
# 2025-05-02  1.129650  1.127912  1.096363  56.764865  0.012059     0.014322
# 2025-05-05  1.132323  1.129605  1.098086  58.266819  0.011148     0.013687

# %%
features += ['SMA_diff', 'RSI', 'MACD', 'MACD_signal']

# %%
from ta.trend import SMAIndicator
data['SMA_20'] = SMAIndicator(data['EURUSD'], window=20).sma_indicator()
data['SMA_50'] = SMAIndicator(data['EURUSD'], window=50).sma_indicator()
data['SMA_diff'] = data['SMA_20'] - data['SMA_50']

# %%
data['ML_Signal'] = 0
data.loc[data.index[-len(y_test):], 'ML_Signal'] = y_pred_rf

data['ML_Strategy'] = data['ML_Signal'].shift(1) * data['Returns']
(1 + data[['Returns', 'ML_Strategy']]).cumprod().plot(figsize=(12,5), title='ML Strategy vs Buy & Hold')
# Out:
# <Axes: title={'center': 'ML Strategy vs Buy & Hold'}>

# %%
# !pip install shap --quiet

# %%
print("Shape of shap_values[1]:", shap_values[1].shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of shap_values[1]: (7, 2)
# Shape of X_test: (771, 7)

# %%
print("Shape of shap_values[1]:", shap_values[1].shape)
print("Shape of shap_values[1][:, :-1]:", shap_values[1][:, :-1].shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of shap_values[1]: (7, 2)
# Shape of shap_values[1][:, :-1]: (7, 1)
# Shape of X_test: (771, 7)

# %%
print("X_test columns:", X_test.columns)
# Out:
# X_test columns: Index(['Lag1', 'Lag2', 'Lag3', 'DXY_Change', 'CPI_Change', 'FFR_Change',
#        'US10Y_Change'],
#       dtype='object')

# %%
print("X_train columns:", X_train.columns)
# Out:
# X_train columns: Index(['Lag1', 'Lag2', 'Lag3', 'DXY_Change', 'CPI_Change', 'FFR_Change',
#        'US10Y_Change'],
#       dtype='object')

# %%
pip install --upgrade shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("X_train columns:", X_train.columns.tolist())
print("X_test columns:", X_test.columns.tolist())
print("y_train unique values:", np.unique(y_train))
# Out:
# X_train shape: (800, 10)
# y_train shape: (800,)
# X_test shape: (200, 10)
# X_train columns: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9']
# X_test columns: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9']
# y_train unique values: [0 1]

# %%
import shap

# Initialize the TreeExplainer for Random Forest
explainer = shap.TreeExplainer(rf_model)

# Compute SHAP values for your test data
shap_values = explainer.shap_values(X_test)

# %%
print("X_test shape:", X_test.shape)
print("shap_values shape:", np.array(shap_values).shape)
# Out:
# X_test shape: (200, 10)
# shap_values shape: (200, 10, 2)

# %%
shap.summary_plot(shap_values[:, :, 1], X_test)

# %%
print(X_test.columns.tolist())
# Out:
# ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9']

# %%
data['EURUSD_Returns'] = data['EURUSD'].pct_change(fill_method=None)
data['DXY_Change'] = data['DOLLAR_IDX'].pct_change(fill_method=None).shift(1)
data['CPI_Change'] = data['CPI'].pct_change(fill_method=None).shift(1)

# %%
data.dropna(inplace=True)

# %%
print("Final shape of X:", X.shape)
print("Final shape of y:", y.shape)
# Out:
# Final shape of X: (0, 11)
# Final shape of y: (0,)

# %%
data['EURUSD_Returns'] = data['EURUSD'].pct_change(fill_method=None)
data['Lag1'] = data['EURUSD_Returns'].shift(1)
data['Lag2'] = data['EURUSD_Returns'].shift(2)
data['Lag3'] = data['EURUSD_Returns'].shift(3)

if use_fred:
    data['DXY_Change'] = data['DOLLAR_IDX'].pct_change(fill_method=None).shift(1)
    data['CPI_Change'] = data['CPI'].pct_change(fill_method=None).shift(1)
    data['FFR_Change'] = data['FEDFUNDS'].diff().shift(1)
    data['US10Y_Change'] = data['US10Y'].diff().shift(1)

# Technical indicators...
# ...

data['Target'] = (data['EURUSD_Returns'].shift(-1) > 0).astype(int)

# ✅ Drop rows only after all columns are ready
data.dropna(inplace=True)
